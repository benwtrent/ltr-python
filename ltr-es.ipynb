# %% [markdown]
# All of this was adjusted from [Doug Turnbull's excellent blog](https://softwaredoug.com/blog/2021/11/28/how-lammbamart-works.html) and [his excellent notebook](https://github.com/softwaredoug/hello-ltr/blob/lambda-mart-in-python/notebooks/elasticsearch/tmdb/lambda-mart-in-python.ipynb)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ltr.client import ElasticClient
from elasticsearch import Elasticsearch
client = ElasticClient()

# %%
from ltr import download
corpus='http://es-learn-to-rank.labs.o19s.com/tmdb.json'
judgments='http://es-learn-to-rank.labs.o19s.com/title_judgments.txt'

download([corpus, judgments], dest='data/');
from ltr.index import rebuild
from ltr.helpers.movies import indexable_movies

movies=indexable_movies(movies='data/tmdb.json')
rebuild(client, index='tmdb', doc_src=movies)
# Out:
# data/tmdb.json already exists
# data/title_judgments.txt already exists
# Created index tmdb [Status: 200]
# 100%|██████████| 27846/27846 [00:18<00:00, 1525.15it/s]
# Streaming Bulk index DONE tmdb [Status: 201]

# %% [markdown]
# # Features and Judgements
#
# Here we calculate our LTR features and combine them with known document & query judgements. Allowing us to combine into a larger feature training data set that includes
# `qid`, `doc`, `features`, `ranking`
#
# This can then be adjusted with the "lambdas" for training the model!!!

# %%
from ltr.log import FeatureLogger
from ltr.judgments import judgments_open
from itertools import groupby
from ltr.judgments import judgments_to_dataframe

# Query features, the _score output of the query is the LTR feature value
query_feature_names = [
    "title_bm25",
    "overview_bm25",
    "title_phrase_bm25",
    "overview_phrase_bm25",
]
query_feature_templates = [
                {"match": {"title": "{{keywords}}"}},
                {"match": {"overview": "{{keywords}}"}},
                {"match_phrase": {"title": "{{keywords}}"}},
                {"match_phrase": {"overview": "{{keywords}}"}},
        ]

# Log features for each query
ftr_logger = FeatureLogger(
    client,
    index="tmdb",
    feature_names=query_feature_names,
    feature_templates=query_feature_templates,
)
with judgments_open("data/title_judgments.txt") as judgment_list:
    for qid, query_judgments in groupby(judgment_list, key=lambda j: j.qid):
        ftr_logger.log_for_qid(
            judgments=query_judgments, qid=qid, keywords=judgment_list.keywords(qid)
        )

# Convert to Pandas Dataframe
judgments = judgments_to_dataframe(ftr_logger.logged, unnest=False)
judgments
# Out:
# Recognizing 40 queries in: data/title_judgments.txt
#            uid  qid   keywords   docId  grade  \
# 0       1_7555    1      rambo    7555      4
# 1       1_1370    1      rambo    1370      3
# 2       1_1369    1      rambo    1369      3
# 3      1_13258    1      rambo   13258      2
# 4       1_1368    1      rambo    1368      4
# ..         ...  ...        ...     ...    ...
# 768   40_81899   40  star wars   81899      0
# 769   40_54138   40  star wars   54138      0
# 770  40_188927   40  star wars  188927      0
# 771     40_200   40  star wars     200      0
# 772  40_325553   40  star wars  325553      1
#
#                                          features
# 0    [11.657399, 10.083591, 11.657399, 10.083591]
# 1      [9.456276, 13.265001, 9.456276, 13.265001]
# 2      [6.036743, 11.113943, 6.036743, 11.113943]
# 3                      [0, 6.869545, 0, 6.869545]
# 4                    [0, 11.113943, 0, 11.113943]
# ..                                            ...
# 768                   [0, 6.868508, 0, 4.2289925]
# 769                   [4.962413, 2.2779262, 0, 0]
# 770                           [4.962413, 0, 0, 0]
# 771                           [4.962413, 0, 0, 0]
# 772                           [0, 3.276606, 0, 0]
#
# [773 rows x 6 columns]

# %% [markdown]
# Lets calculate those lambdas!

# %%
from math import log, exp
import numpy as np 

def rank_with_swap(ranked_list, rank1=0, rank2=0):
    """ Set the display rank of positions given the provided swap """
    ranked_list['display_rank'] = ranked_list.index.to_series()
    
    if rank1 != rank2:
        ranked_list.loc[rank1, 'display_rank'] = rank2
        ranked_list.loc[rank2, 'display_rank'] = rank1
    return ranked_list
    

def dcg(ranked_list, at=10):
    """Given a list, compute DCG -- 
       uses same variant as lambdamart 2**grade / log2(displayrank)
    """
    ranked_list['discount'] = 1 / np.log2(2 + ranked_list['display_rank'])
    ranked_list['gain'] = (2**ranked_list['grade'] - 1) * ranked_list['discount'] # TODO - precompute gain on swapping
    return sum(ranked_list['gain'].head(at))

def compute_swaps(query_judgments, axis, metric=dcg, at=10):
    """Compute the 'lambda' the DCG impact of every query result swapped with every-other query result"""
    
    # Sort to see ideal ordering
    # This isn't strictly nescesarry, but it's helpful to understand the algorithm
    query_judgments = query_judgments.sort_values('grade', kind='stable', ascending=False).reset_index()

    # Instead of explicitly 'swapping' we just swap the 'display_rank' - where 
    # in the final ranking this would be placed. We can easily use that to compute DCG
    query_judgments['display_rank'] = query_judgments.index.to_series()
    query_judgments['dcg'] = metric(query_judgments, at=at)
    best_dcg = query_judgments.loc[0, 'dcg']

    query_judgments['lambda'] = 0.0
    
    # TODO - redo inner body as 
    for better in range(0,len(query_judgments)):
        for worse in range(0,len(query_judgments)):
            if better > at and worse > at:
                break

            if query_judgments.loc[better, 'grade'] > query_judgments.loc[worse, 'grade']:
                query_judgments = rank_with_swap(query_judgments, better, worse)
                query_judgments['dcg'] = metric(query_judgments, at=at)

                dcg_after_swap = query_judgments.loc[0, 'dcg']
                delta = abs(best_dcg - dcg_after_swap)

                if delta > 0.0:

                    # Add delta to better's lambda (-delta to worse's lambda)
                    query_judgments.loc[better, 'lambda'] += delta
                    query_judgments.loc[worse, 'lambda'] -= delta

    # print(query_judgments[['keywords', 'docId', 'grade', 'lambda', 'features']])
    return query_judgments

# For each query, compute lambdas
# %prun -s cumulative lambdas_per_query = judgments.groupby('qid').apply(compute_swaps, axis=1)
# judgments
lambdas_per_query = judgments.groupby('qid').apply(compute_swaps, axis=1)
lambdas_per_query
# Out:
#         index        uid  qid   keywords   docId  grade  \
# qid
# 1   0       0     1_7555    1      rambo    7555      4
#     1       4     1_1368    1      rambo    1368      4
#     2       1     1_1370    1      rambo    1370      3
#     3       2     1_1369    1      rambo    1369      3
#     4       3    1_13258    1      rambo   13258      2
# ...       ...        ...  ...        ...     ...    ...
# 40  10    767  40_209276   40  star wars  209276      0
#     11    768   40_81899   40  star wars   81899      0
#     12    769   40_54138   40  star wars   54138      0
#     13    770  40_188927   40  star wars  188927      0
#     14    771     40_200   40  star wars     200      0
#
#                                             features  display_rank  discount  \
# qid
# 1   0   [11.657399, 10.083591, 11.657399, 10.083591]             0  1.000000
#     1                   [0, 11.113943, 0, 11.113943]             1  0.630930
#     2     [9.456276, 13.265001, 9.456276, 13.265001]             2  0.500000
#     3     [6.036743, 11.113943, 6.036743, 11.113943]             3  0.430677
#     4                     [0, 6.869545, 0, 6.869545]             6  0.333333
# ...                                              ...           ...       ...
# 40  10                          [5.8994045, 0, 0, 0]            10  0.278943
#     11                   [0, 6.868508, 0, 4.2289925]            11  0.270238
#     12                   [4.962413, 2.2779262, 0, 0]            12  0.262650
#     13                           [4.962413, 0, 0, 0]            13  0.255958
#     14                           [4.962413, 0, 0, 0]             7  0.315465
#
#              gain        dcg     lambda
# qid
# 1   0   15.000000  32.721742  34.258787
#     1    9.463946  32.721742  13.590853
#     2    3.500000  32.721742  -2.732092
#     3    3.014736  32.721742  -4.950443
#     4    1.000000  32.721742 -10.746243
# ...           ...        ...        ...
# 40  10   0.000000  28.743757 -16.535733
#     11   0.000000  28.743757 -16.918744
#     12   0.000000  28.743757 -17.252643
#     13   0.000000  28.743757 -17.547069
#     14   0.000000  28.743757 -17.809222
#
# [773 rows x 12 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

class OverridenRegressionTree:
    def __init__(self, predictions, tree):
        self.predictions = predictions
        self.tree = tree
        
    def predict(self, X, use_original=False):
        if use_original:
            return self.predict(X)
        path = self.tree.decision_path(X).toarray().astype(str)
        path = "".join(path[0])
        
        paths_as_array = self.tree.decision_path(X).toarray()
        paths = ["".join(item) for item in paths_as_array.astype(str)]
        
        predictions = self.predictions[paths]
        
        # Any NaN predictions is a red flag, debug
        if np.any(predictions.isnull()):
            print(predictions[predictions.isnull()])
            print(pd.DataFrame(X)[predictions.isnull().reset_index(drop=True)])
            raise AssertionError("No prediction should be NaN")
        return np.array(self.predictions[paths].tolist())



def compute_swaps_scaled_with_weights(query_judgments, axis, metric=dcg, at=10):
    """Compute the 'lambda' the DCG impact of every query result swapped with every-other query result
    
    
    """
    
    # Sort to see ideal ordering
    # This isn't strictly nescesarry, but it's helpful to understand the algorithm
    query_judgments = query_judgments.sort_values('last_prediction', ascending=False, kind='stable').reset_index()

    # Instead of explicitly 'swapping' we just swap the 'display_rank' - where 
    # in the final ranking this would be placed. We can easily use that to compute DCG
    query_judgments['display_rank'] = query_judgments.index.to_series()
    query_judgments['train_dcg'] = query_judgments['dcg'] = metric(query_judgments, at=at)
    train_dcg = query_judgments.loc[0, 'dcg']
 
    qid = query_judgments.loc[0, 'qid']
    keywords = query_judgments.loc[0, 'keywords']


    query_judgments['lambda'] = 0.0
    query_judgments['weight'] = 0.0

    for better in range(0,len(query_judgments)):
         for worse in range(0,len(query_judgments)):
            if better > at and worse > at:
                return query_judgments
                
            if query_judgments.loc[better, 'grade'] > query_judgments.loc[worse, 'grade']:
                query_judgments = rank_with_swap(query_judgments, better, worse)
                query_judgments['dcg'] = metric(query_judgments, at=at)

                dcg_after_swap = query_judgments.loc[0, 'dcg']
                delta = abs(train_dcg - dcg_after_swap)

                if delta != 0.0:
                    last_model_score_diff = query_judgments.loc[better, 'last_prediction'] - query_judgments.loc[worse, 'last_prediction']
                    rho = 1.0 / (1.0 + exp(last_model_score_diff)) 

                    assert(delta >= 0.0)
                    assert(rho >= 0.0)
                   
                    query_judgments.loc[better, 'lambda'] += delta * rho
                    query_judgments.loc[worse, 'lambda'] -= delta * rho
            
                    # --------------
                    # NEW!
                    #  last_model_score_diff        rho         weight
                    #      0.0                      0.5         0.25 (max possible value)
                    #      100.0                    0.0000      0.0  (max possible value)
                    # 
                    # If the current model has an ambiguous prediction, we include more of the delta in the weight
                    # If the current model has a strong prediction, weight approaches 0
                    query_judgments.loc[better, 'weight'] += rho * (1.0 - rho) * delta;
                    query_judgments.loc[worse, 'weight'] += rho * (1.0 - rho) * delta;
                    #
                    # These will be used to rescale each decision tree node's predictions
                    # If many results in a leaf node have last model score ~ ambiguous
                    #     the resulting model will have a high denominator ~ (1 / deltaDCG)
                    # If many results in a leaf node have last model score - not ambiguous, positive
                    #     the resulting model will have a low denominator
                    #
                    # Apparently we want to cancel out the deltas if last model was ambiguous?
                    # ---------------

                    

    return query_judgments

def predict(ensemble, X, learning_rate=0.1):
    prediction = 0
    for tree in ensemble:
        prediction += tree.predict(X) * learning_rate
    return prediction.rename('prediction')


def tree_paths(tree, X):
    paths_as_array = tree.decision_path(X).toarray()
    paths = ["".join(item) for item in paths_as_array.astype(str)]
    return paths

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

class OverridenRegressionTree:
    def __init__(self, predictions, tree):
        self.predictions = predictions
        self.tree = tree
        
    def predict(self, X, use_original=False):
        if use_original:
            return self.predict(X)
        path = self.tree.decision_path(X).toarray().astype(str)
        path = "".join(path[0])
        
        paths_as_array = self.tree.decision_path(X).toarray()
        paths = ["".join(item) for item in paths_as_array.astype(str)]
        
        predictions = self.predictions[paths]
        
        # Any NaN predictions is a red flag, debug
        if np.any(predictions.isnull()):
            print(predictions[predictions.isnull()])
            print(pd.DataFrame(X)[predictions.isnull().reset_index(drop=True)])
            raise AssertionError("No prediction should be NaN")
        return np.array(self.predictions[paths].tolist())

def compute_lambdas(lambdas_per_query):
    lambdas_per_query = lambdas_per_query.sort_values(['qid', 'last_prediction'], ascending=[True, False], kind='stable')
    lambdas_per_query['display_rank'] = lambdas_per_query.groupby('qid').cumcount()

    #TBD - How do generalize this to any metric?
    lambdas_per_query['discount'] = 1 / np.log2(2 + lambdas_per_query['display_rank'])
    lambdas_per_query['gain'] = (2**lambdas_per_query['grade'] - 1)

    # swaps dataframe holds each pair-wise swap computed (shrink columns for memory?)   
    # Optimization of swaps = lambdas_per_query.merge(lambdas_per_query, on='qid', how='outer')
    # to limit to just needed columns
    to_swap = lambdas_per_query[['qid', 'display_rank', 'grade', 'last_prediction', 'discount', 'gain']]
    #to_swap = lambdas_per_query
    swaps = to_swap.merge(to_swap, on='qid', how='outer')

    # delta - delta in DCG due to swap
    swaps['delta'] = np.abs((swaps['discount_x'] - swaps['discount_y']) * (swaps['gain_x'] - swaps['gain_y']))
    
    # rho - based on current model prediction delta
    swaps['rho'] = 1 / (1 + np.exp(swaps['last_prediction_x'] - swaps['last_prediction_y']))
    
    # If you want to be pure gradient boosting, weight reweights each models prediction
    # I haven't found this to matter in practice
    swaps['weight'] = swaps['rho'] * (1.0 - swaps['rho']) * swaps['delta']

    # Compute lambdas (the next model in ensemble's predictors) when grade_x > grade_y
    swaps['lambda'] = 0
    slice_x_better =swaps[swaps['grade_x'] > swaps['grade_y']]
    swaps.loc[swaps['grade_x'] > swaps['grade_y'], 'lambda'] = slice_x_better['delta'] * slice_x_better['rho']
    
    # accumulate lambdas and add back to model
    lambdas_x = swaps.groupby(['qid', 'display_rank_x'])['lambda'].sum().rename('lambda')
    lambdas_y = swaps.groupby(['qid', 'display_rank_y'])['lambda'].sum().rename('lambda')

    weights_x = swaps.groupby(['qid', 'display_rank_x'])['weight'].sum().rename('weight')
    weights_y = swaps.groupby(['qid', 'display_rank_y'])['weight'].sum().rename('weight')
    
    weights = weights_x + weights_y
    lambdas = lambdas_x - lambdas_y

    lambdas_per_query = lambdas_per_query.merge(lambdas, 
                                                left_on=['qid', 'display_rank'], 
                                                right_on=['qid', 'display_rank_x'], 
                                                how='left')
    lambdas_per_query = lambdas_per_query.merge(weights, 
                                                left_on=['qid', 'display_rank'], 
                                                right_on=['qid', 'display_rank_x'], 
                                                how='left')

    return lambdas_per_query

from sklearn.tree import DecisionTreeRegressor
import pandas as pd


ensemble=[]
def lambda_mart_pure(judgments, rounds=20, learning_rate=0.1, max_leaf_nodes=8, metric=dcg):

    print(judgments.columns)
    # Convert to Pandas Dataframe
    lambdas_per_query = judgments.copy()


    lambdas_per_query['last_prediction'] = 0.0

    for i in range(0, rounds):
        print(f"round {i}")

        # ------------------
        #1. Build pair-wise predictors for this round
        lambdas_per_query = compute_lambdas(lambdas_per_query)

        # ------------------
        #2. Train a regression tree on this round's lambdas
        features = lambdas_per_query['features'].tolist()
        tree = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes)
        tree.fit(features, lambdas_per_query['lambda'])    

        # ------------------
        #3. Reweight based on LambdaMART's weighted average
        # Add each tree's paths
        lambdas_per_query['path'] = tree_paths(tree, features)
        predictions = lambdas_per_query.groupby('path')['lambda'].sum() / lambdas_per_query.groupby('path')['weight'].sum()
        predictions = predictions.fillna(0.0) # for divide by 0

        # -------------------
        #4. Add to ensemble, recreate last prediction
        new_tree = OverridenRegressionTree(predictions=predictions, tree=tree)
        ensemble.append(new_tree)
        next_predictions = new_tree.predict(features)
        lambdas_per_query['last_prediction'] += (next_predictions * learning_rate) 
        
        print(lambdas_per_query.loc[0, ['grade', 'last_prediction']])
        
        print("Train DCGs")
        lambdas_per_query['discounted_gain'] = lambdas_per_query['gain'] * lambdas_per_query['discount'] 
        dcg = lambdas_per_query[lambdas_per_query['display_rank'] < 10].groupby('qid')['discounted_gain'].sum().mean()
        print("mean   ", dcg)
        print("----------")
        
        lambdas_per_query = lambdas_per_query.drop(['lambda', 'weight'], axis=1)
    return lambdas_per_query


judgments = judgments_to_dataframe(ftr_logger.logged, unnest=False)
lambdas_per_query = lambda_mart_pure(judgments=judgments, rounds=50, max_leaf_nodes=10, learning_rate=0.01, metric=dcg)
# Out:
# Index(['uid', 'qid', 'keywords', 'docId', 'grade', 'features'], dtype='object')
# round 0
# grade                     4
# last_prediction    0.009711
# Name: 0, dtype: object
# Train DCGs
# mean    20.83415007369131
# ----------
# round 1
# grade                     4
# last_prediction    0.019372
# Name: 0, dtype: object
# Train DCGs
# mean    20.442853108353383
# ----------
# round 2
# grade                     4
# last_prediction    0.028972
# Name: 0, dtype: object
# Train DCGs
# mean    20.579760132996235
# ----------
# round 3
# grade                     4
# last_prediction    0.038468
# Name: 0, dtype: object
# Train DCGs
# mean    20.442853108353383
# ----------
# round 4
# grade                     4
# last_prediction    0.047907
# Name: 0, dtype: object
# Train DCGs
# mean    20.579760132996235
# ----------
# round 5
# grade                     4
# last_prediction    0.056911
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 6
# grade                     4
# last_prediction    0.065844
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 7
# grade                     4
# last_prediction    0.074708
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 8
# grade                     4
# last_prediction    0.083504
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 9
# grade                     4
# last_prediction    0.092235
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 10
# grade                   4
# last_prediction    0.1009
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 11
# grade                     4
# last_prediction    0.109502
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 12
# grade                     4
# last_prediction    0.118042
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 13
# grade                     4
# last_prediction    0.126522
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 14
# grade                     4
# last_prediction    0.134943
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 15
# grade                     4
# last_prediction    0.143305
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 16
# grade                     4
# last_prediction    0.151611
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 17
# grade                     4
# last_prediction    0.159862
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 18
# grade                     4
# last_prediction    0.168058
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 19
# grade                     4
# last_prediction    0.176201
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 20
# grade                     4
# last_prediction    0.184291
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 21
# grade                     4
# last_prediction    0.192331
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 22
# grade                    4
# last_prediction    0.20032
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 23
# grade                     4
# last_prediction    0.208261
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 24
# grade                     4
# last_prediction    0.216153
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 25
# grade                     4
# last_prediction    0.223998
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 26
# grade                     4
# last_prediction    0.231797
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 27
# grade                    4
# last_prediction    0.23955
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 28
# grade                     4
# last_prediction    0.247259
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 29
# grade                     4
# last_prediction    0.254924
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 30
# grade                     4
# last_prediction    0.262546
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 31
# grade                     4
# last_prediction    0.270126
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 32
# grade                     4
# last_prediction    0.277665
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 33
# grade                     4
# last_prediction    0.285163
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 34
# grade                     4
# last_prediction    0.292622
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 35
# grade                     4
# last_prediction    0.300041
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 36
# grade                     4
# last_prediction    0.307421
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 37
# grade                     4
# last_prediction    0.314764
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 38
# grade                    4
# last_prediction    0.32207
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 39
# grade                     4
# last_prediction    0.329339
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 40
# grade                     4
# last_prediction    0.336572
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 41
# grade                    4
# last_prediction    0.34377
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 42
# grade                     4
# last_prediction    0.350933
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 43
# grade                     4
# last_prediction    0.358063
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 44
# grade                     4
# last_prediction    0.365158
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 45
# grade                     4
# last_prediction    0.372221
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 46
# grade                     4
# last_prediction    0.379251
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 47
# grade                     4
# last_prediction    0.386249
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 48
# grade                     4
# last_prediction    0.393215
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------
# round 49
# grade                     4
# last_prediction    0.400151
# Name: 0, dtype: object
# Train DCGs
# mean    20.53213203442482
# ----------

# %% [markdown]
# Create the model from the ensemble!

# %%
from eland.ml import MLModel, ml_model
from eland.ml.transformers import get_model_transformer
from eland.ml._model_serializer import Ensemble
from elasticsearch import Elasticsearch
import json
import gzip
import base64

trained_models = [get_model_transformer(m.tree, feature_names=query_feature_names).transform() for m in ensemble]

ensemble_aggregator_output = {
            "weighted_sum": {
                "weights": [1.0 / len(trained_models)]
                * len(trained_models),
            }
        }

es_model =Ensemble(
            query_feature_names,
            trained_models,
            ensemble_aggregator_output,
            target_type="regression",
        )
es_model.serialize_model()
# Out:
# {'trained_model': {'ensemble': {'target_type': 'regression',
#    'feature_names': ['title_bm25',
#     'overview_bm25',
#     'title_phrase_bm25',
#     'overview_phrase_bm25'],
#    'trained_models': [{'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 1,
#         'threshold': 8.648598670959473,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 32},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 1,
#         'threshold': 15.53025770187378,
#         'number_samples': 19},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 13},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 127.7667804490109},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 59.08713576790342},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -5.071359708741676},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 141.97151575859138},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 11.573134048510138},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 49.68586185739585},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 148.7602644730592},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 28.25836311482372},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 15.53232192993164,
#         'number_samples': 7},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 101.75302208737124},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 35.816211901707355}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 1,
#         'threshold': 8.648598670959473,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 32},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 20.519166946411133,
#         'number_samples': 19},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 2,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 13},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 126.61941453695161},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 12.771522998809814,
#         'number_samples': 5},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.99772659747796},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 140.69296738818446},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.789759354605659},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 48.888142652162124},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 147.43365078923972},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 34.19593739174629},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'leaf_value': 93.3026623359043},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 38.02598405078796},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 101.30683386258451}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 1,
#         'threshold': 8.648598670959473,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 32},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 1,
#         'threshold': 15.53025770187378,
#         'number_samples': 19},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 2,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 13},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 125.47749217552429},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 12.771522998809814,
#         'number_samples': 5},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.963325484277115},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 139.42047822396694},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.692781366218847},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 52.92637194161588},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 146.11332999706516},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.223720349002758},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'leaf_value': 92.45882879745092},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 27.495746025738118},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 58.651015989687025}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 1,
#         'threshold': 8.648598670959473,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 32},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 20.519166946411133,
#         'number_samples': 19},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 2,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 13},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 124.34625896970543},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 12.771523475646973,
#         'number_samples': 5},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.909073862900991},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 138.159915043198},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.596541434317771},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 49.965848575201946},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 144.80527774978964},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.03951557618575},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'leaf_value': 91.62290296122877},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 37.35218321895806},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 99.49452911627596}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 1,
#         'threshold': 8.648598670959473,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 32},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 1,
#         'threshold': 15.53025770187378,
#         'number_samples': 19},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 13},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 123.22497436314953},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 3,
#         'threshold': 7.359540939331055,
#         'number_samples': 5},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.875195098147238},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 136.91045673288264},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.501165788085007},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 51.99901098433517},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 143.50873781869856},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 21.856842190918048},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'leaf_value': 90.7943403721306},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 27.012912499057105},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 57.60291168379145}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 122.11422239107301},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 51.18843041775047},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.837480763530727},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 135.67275005269866},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.406660665684344},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 50.290033711520465},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 142.22428326092998},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 23.869728320135838},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 97.49741420331745},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 27.810245371858887}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 121.01344674590484},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 50.491945832198},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.794365366773},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 134.44620959003393},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.313249004483014},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 49.84773708406985},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 140.95135339100108},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 23.66439642843397},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 15.53232192993164,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 96.61877243386817},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 27.7974696521737}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 119.92272629405268},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 50.04008058428742},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.751640926434392},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 133.2308737248702},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.22068250428844},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 49.409419596963915},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 139.68999497622494},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 23.460879937000566},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 95.7481417691075},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 27.546578006710767}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 118.84196743180124},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 49.59232651013768},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.709304045480438},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 132.02665325742524},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.128953808904555},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 48.97505105963075},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 138.44011715939718},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 23.2591718744316},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 15.53232192993164,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 94.88545867201799},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 27.297977957134506}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 2,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 117.7710906664343},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 49.148650956340255},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.667351628562002},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 130.8334591430169},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 10.038055617763968},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 48.54460044491376},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 137.20162919586838},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 23.059258037891336},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 94.03065970882786},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 27.051650994963993}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 116.7100166319801},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 48.70902132012467},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.625780586486388},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 129.65120249147031},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 9.947980681893874},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 48.11803676877141},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 135.97444045439437},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.861124251855447},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 15.53232192993164,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 93.18368154874491},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 26.80757865374668}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 115.65866611591606},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 48.273405060339954},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.5845878371841975},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 128.47979459644276},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 9.858721804417941},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 47.695329100736906},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 134.75846044907698},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.664756372328544},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 92.34446098510158},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 26.5657425146845}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 2,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 114.6169600841746},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 47.84176970773748},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.543770306613568},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 127.31914696287325},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 9.77027184098303},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 47.27644657372182},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 133.55359886929656},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.470140290797115},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 91.51293495515657},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 26.326124211888086}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 113.58481970455261},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 47.4140828745978},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.503324929605626},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 126.16917133267097},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 9.682623700116777},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 46.861358393203},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 132.35976560775805},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.27726193793387},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 15.53232192993164,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 90.6890405586348},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 26.08870543728225}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 2,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 112.56216636862239},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 46.99031226374148},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -4.463248650654884},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 125.02977970874979},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 9.595770343521684},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 46.45003384583018},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 131.17687078676448},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 22.086107287068263},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 2,
#         'threshold': 15.53232192993164,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 89.87271507508198},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 25.85346794518418}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 111.54892171223288},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 46.57042567696061},
#        {'node_index': 9,
# ...
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 85.15190978679732},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 35.6258847728971},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -3.387910515897572},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 94.49569633733186},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 7.2616066940851995},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 35.403877882903664},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 99.45882234865131},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 16.941503201274795},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 67.99085129243603},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 19.547380448318847}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 84.39341882425695},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 35.31122798277852},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -3.3581164520411377},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 93.6509050217822},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 7.196788627770081},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 35.09755293314764},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 98.58077350903109},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 16.79847456802987},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 67.38527956666458},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 19.372835807538827}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 83.64203025446103},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 34.9995069325444},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -3.328599066395589},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 92.81403189491891},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 7.132562647669484},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 34.79405690006938},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 97.71092745060069},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 16.656744064611583},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 66.78537433838002},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 19.199922430073276}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 0,
#         'threshold': 13.143222332000732,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 82.89767949753914},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 34.690695047532486},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -3.299355859858143},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 2,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 91.98500483751602},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 7.068923462315863},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 34.49336438765571},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 96.84920989878704},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 16.516300140263365},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 66.19108408922916},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 19.028625486316905}]}},
#     {'tree': {'target_type': 'regression',
#       'feature_names': ['title_bm25',
#        'overview_bm25',
#        'title_phrase_bm25',
#        'overview_phrase_bm25'],
#       'tree_structure': [{'node_index': 0,
#         'decision_type': 'lte',
#         'left_child': 1,
#         'right_child': 2,
#         'split_feature': 2,
#         'threshold': 9.72804069519043,
#         'number_samples': 773},
#        {'node_index': 1,
#         'decision_type': 'lte',
#         'left_child': 9,
#         'right_child': 10,
#         'split_feature': 2,
#         'threshold': 8.166615962982178,
#         'number_samples': 722},
#        {'node_index': 2,
#         'decision_type': 'lte',
#         'left_child': 3,
#         'right_child': 4,
#         'split_feature': 3,
#         'threshold': 2.825845718383789,
#         'number_samples': 51},
#        {'node_index': 3,
#         'decision_type': 'lte',
#         'left_child': 5,
#         'right_child': 6,
#         'split_feature': 1,
#         'threshold': 0.89048171043396,
#         'number_samples': 31},
#        {'node_index': 4,
#         'decision_type': 'lte',
#         'left_child': 15,
#         'right_child': 16,
#         'split_feature': 2,
#         'threshold': 13.143220901489258,
#         'number_samples': 20},
#        {'node_index': 5,
#         'decision_type': 'lte',
#         'left_child': 13,
#         'right_child': 14,
#         'split_feature': 0,
#         'threshold': 20.846759796142578,
#         'number_samples': 19},
#        {'node_index': 6,
#         'decision_type': 'lte',
#         'left_child': 7,
#         'right_child': 8,
#         'split_feature': 1,
#         'threshold': 9.621058464050293,
#         'number_samples': 12},
#        {'node_index': 7,
#         'decision_type': 'lte',
#         'leaf_value': 82.16030245721501},
#        {'node_index': 8,
#         'decision_type': 'lte',
#         'leaf_value': 34.384765950795064},
#        {'node_index': 9,
#         'decision_type': 'lte',
#         'leaf_value': -3.270384352097758},
#        {'node_index': 10,
#         'decision_type': 'lte',
#         'left_child': 11,
#         'right_child': 12,
#         'split_feature': 0,
#         'threshold': 8.241753101348877,
#         'number_samples': 23},
#        {'node_index': 11,
#         'decision_type': 'lte',
#         'leaf_value': 91.16375227351394},
#        {'node_index': 12,
#         'decision_type': 'lte',
#         'leaf_value': 7.005865826536902},
#        {'node_index': 13,
#         'decision_type': 'lte',
#         'leaf_value': 34.19545018565},
#        {'node_index': 14,
#         'decision_type': 'lte',
#         'leaf_value': 95.99554712734556},
#        {'node_index': 15,
#         'decision_type': 'lte',
#         'leaf_value': 16.37713132853344},
#        {'node_index': 16,
#         'decision_type': 'lte',
#         'left_child': 17,
#         'right_child': 18,
#         'split_feature': 0,
#         'threshold': 15.532322406768799,
#         'number_samples': 8},
#        {'node_index': 17,
#         'decision_type': 'lte',
#         'leaf_value': 65.60235768660084},
#        {'node_index': 18,
#         'decision_type': 'lte',
#         'leaf_value': 18.858930260063786}]}}],
#    'aggregate_output': {'weighted_sum': {'weights': [0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02,
#       0.02]}}}}}

# %% [markdown]
# Put the model! HUZZAH!

# %%
es = Elasticsearch('http://127.0.0.1:9200')
model_dict = es_model.serialize_model()
json_string = json.dumps(model_dict, separators=(",", ":"))
compressed_string = base64.b64encode(gzip.compress(json_string.encode("utf-8"))).decode("ascii")

es.ml.put_trained_model(
    model_id="ltr-part-4", 
    body={
        # only put in field_names you want extracted from document field names
        "input" : {"field_names": ["vote_average"]},
        "inference_config" : {"learn_to_rank": {}},
        "compressed_definition": compressed_string,
    }
)
# Out:
# /var/folders/vg/q43_zcls7_52j34ct3l3tyn80000gn/T/ipykernel_9155/4082751687.py:6: DeprecationWarning:
#
# The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
# ObjectApiResponse({'model_id': 'ltr-part-4', 'model_type': 'tree_ensemble', 'created_by': 'api_user', 'version': '10.0.0', 'create_time': 1692629118534, 'model_size_bytes': 91120, 'estimated_operations': 105, 'license_level': 'platinum', 'tags': [], 'input': {'field_names': ['vote_average']}, 'inference_config': {'learn_to_rank': {'num_top_feature_importance_values': 0}}})

# %%
#POST _search
template = {
  "rescore": {
    "window_size": 10,
    "inference": {
      "model_id": "ltr-part-4",
      "inference_config": {
        "learn_to_rank": {"feature_extractors":[{"query_extractor": {"feature_name": feature_name, "query": query}} for (feature_name, query) in zip(query_feature_names, query_feature_templates)]}
      }
    }
  }
}
template = {"source": template}
template
# Out:
# {'source': {'rescore': {'window_size': 10,
#    'inference': {'model_id': 'ltr-part-4',
#     'inference_config': {'learn_to_rank': {'feature_extractors': [{'query_extractor': {'feature_name': 'title_bm25',
#          'query': {'match': {'title': '{{keywords}}'}}}},
#        {'query_extractor': {'feature_name': 'overview_bm25',
#          'query': {'match': {'overview': '{{keywords}}'}}}},
#        {'query_extractor': {'feature_name': 'title_phrase_bm25',
#          'query': {'match_phrase': {'title': '{{keywords}}'}}}},
#        {'query_extractor': {'feature_name': 'overview_phrase_bm25',
#          'query': {'match_phrase': {'overview': '{{keywords}}'}}}}]}}}}}}

# %%
es.search_template(index='tmdb', body=template, params={'keywords': 'star trek', 'query_dsl': {'match_all': {}}})
# Out:
# /var/folders/vg/q43_zcls7_52j34ct3l3tyn80000gn/T/ipykernel_9155/264152915.py:1: DeprecationWarning:
#
# The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
# ObjectApiResponse({'took': 67, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 10000, 'relation': 'gte'}, 'max_score': 27.886772, 'hits': [{'_index': 'tmdb', '_id': '374430', '_score': 27.886772, '_source': {'id': '374430', 'title': 'Black Mirror: White Christmas', 'overview': "This feature-length special consists of three interwoven stories. In a mysterious and remote snowy outpost, Matt and Potter share a Christmas meal, swapping creepy tales of their earlier lives in the outside world. Matt is a charismatic American trying to bring the reserved, secretive Potter out of his shell. But are both men who they appear to be? A woman gets thrust into a nightmarish world of 'smart' gadgetry. Plus a look at what would happen if you could 'block' people in real life.", 'tagline': '', 'directors': ['Carl Tibbetts'], 'cast': 'Jon Hamm Rafe Spall Oona Chaplin Natalia Tena Janet Montgomery Rasmus Hardiker Dan Li Ken Drury Zahra Ahmadi Verity Marshall Ian Keir Attard', 'genres': ['Drama', 'Horror', 'Mystery', 'Science Fiction', 'Thriller', 'TV Movie'], 'release_date': '2014-12-16', 'release_year': '2014', 'poster_path': 'https://image.tmdb.org/t/p/w185/he609rnU3tiwBjRklKNa4n2jQSd.jpg', 'vote_average': 8.6, 'vote_count': 93}}, {'_index': 'tmdb', '_id': '19404', '_score': 27.886772, '_source': {'id': '19404', 'title': 'The Brave-Hearted Will Take the Bride', 'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.', 'tagline': 'Come Fall In Love', 'directors': ['Aditya Chopra'], 'cast': 'Shah Rukh Khan Kajol Amrish Puri Anupam Kher Satish Shah Achala Sachdev Himani Shivpuri Pooja Ruparel Mandira Bedi Uday Chopra Parmeet Sethi Tulika Chaudhary Pallavi Vyas Karan Johar Arjun Sablok Anaita Shroff Baby Raashi Baby Nupur Shanker Iyer Rajesh Bhatija Govind Khatri Mansoor Merchant Mohit Kumar Hemlata Deepak Lalit Tiwari Damyanti Puri Farida Jalal', 'genres': ['Comedy', 'Drama', 'Romance'], 'release_date': '1995-10-19', 'release_year': '1995', 'poster_path': 'https://image.tmdb.org/t/p/w185/2gvbZMtV1Zsl7FedJa5ysbpBx2G.jpg', 'vote_average': 7.4, 'vote_count': 70}}, {'_index': 'tmdb', '_id': '278', '_score': 27.886772, '_source': {'id': '278', 'title': 'The Shawshank Redemption', 'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'tagline': 'Fear can hold you prisoner. Hope can set you free.', 'directors': ['Frank Darabont'], 'cast': 'Tim Robbins Morgan Freeman Bob Gunton Clancy Brown Mark Rolston James Whitmore Gil Bellows William Sadler Jeffrey DeMunn Larry Brandenburg Neil Giuntoli Brian Libby David Proval Joseph Ragno Jude Ciccolella Paul McCrane Renee Blaine Scott Mann John Horton Gordon Greene Alfonso Freeman V.J. Foster Frank Medrano Mack Miles Gary Lee Davis Ned Bellamy Brian Delate Don McManus Dorothy Silver Dion Anderson Robert Haley Bill Bolender John R. Woodward Rohn Thomas Brian Brophy Ken Magee James Babson Fred Culbertson Alonzo F. Jones Sergio Kato Philip Ettington Neil Summers', 'genres': ['Drama', 'Crime'], 'release_date': '1994-09-23', 'release_year': '1994', 'poster_path': 'https://image.tmdb.org/t/p/w185/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg', 'vote_average': 8.4, 'vote_count': 6703}}, {'_index': 'tmdb', '_id': '372058', '_score': 27.886772, '_source': {'id': '372058', 'title': 'Your Na ...
